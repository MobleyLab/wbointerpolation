# %% [markdown]
# # Bi-aryl molecules
# To construct a series of biaryl molecules with no ortho-substitutents and the bridge bond torsion is defined by the smarts pattern `"[#6X3H1:1]~[#6X3:2](~[#6X3H1])-[#6X3:3](~[#6X3H1])~[#6X3H1:4]"`

# %%
from openff.toolkit.utils.toolkits import ToolkitRegistry, OpenEyeToolkitWrapper, RDKitToolkitWrapper, AmberToolsToolkitWrapper
toolkit_registry = ToolkitRegistry(toolkit_precedence=[OpenEyeToolkitWrapper, RDKitToolkitWrapper, AmberToolsToolkitWrapper])

# %%
def dihedrals_matching_torsion_param(molecule, forcefield, tor_param):
    """
    for a molecule and specific torsion returns matched dihedral indices
    Parameters
    ----------
    molecule: openforcefield molecule object
    ff: ForceField offxml file
    tor_param: torsion parameter to match

    Returns
    -------
    idx_list: list of dihedrals matched to the torsion parameter
    """
    topology = Topology.from_molecules([molecule])
    # Run the molecule labeling
    molecule_force_list = forcefield.label_molecules(topology)

    idx_list = []
    # Print out a formatted description of the parameters applied to this molecule
    for mol_idx, mol_forces in enumerate(molecule_force_list):
        for force_tag, force_dict in mol_forces.items():
            if force_tag == "ProperTorsions":
                for (atom_indices, parameter) in force_dict.items():
                    if (parameter.id == tor_param):
                        idx_list.append(atom_indices)
    return idx_list

# %%
# Import the scaffold object which stores the scaffold definition.
from constructure.scaffolds import Scaffold

# Create the biaryl scaffold.
scaffold_with_aryl = Scaffold(
    smiles="c1cc([R1])ccc1-c2ccc([R2])cc2",
    r_groups={
        1: ["hydrogen", "alkyl", "aryl", "halogen", "hetero", "acyl"],
        2: ["hydrogen", "alkyl", "aryl", "halogen", "hetero", "acyl"],
    },
)

# Create the biaryl scaffold.
scaffold_with_pyridyl = Scaffold(
    smiles="c1cc([R1])ccc1-c2ccnc([R2])c2",
    r_groups={
        1: ["hydrogen", "alkyl", "aryl", "halogen", "hetero", "acyl"],
        2: ["hydrogen", "alkyl", "aryl", "halogen", "hetero", "acyl"],
    },
)

# Create the biaryl scaffold.
scaffold_with_pyridyl_charged = Scaffold(
    smiles="c1cc([R1])ccc1-c2cc[n+](H)c([R2])c2",
    r_groups={
        1: ["hydrogen", "alkyl", "aryl", "halogen", "hetero", "acyl"],
        2: ["hydrogen", "alkyl", "aryl", "halogen", "hetero", "acyl"],
    },
)

# Create the biaryl scaffold.
scaffold_with_pyrrole = Scaffold(
    smiles="c1cc([R1])ccc1-c2cn([R2])cc2",
    r_groups={
        1: ["hydrogen", "alkyl", "aryl", "halogen", "hetero", "acyl"],
        2: ["hydrogen", "alkyl", "aryl", "halogen", "hetero", "acyl"],
    },
)

# Create the biaryl scaffold.
scaffold_with_pyrimidine = Scaffold(
    smiles="c1cc([R1])ccc1-c2cnc([R2])nc2",
    r_groups={
        1: ["hydrogen", "alkyl", "aryl", "halogen", "hetero", "acyl"],
        2: ["hydrogen", "alkyl", "aryl", "halogen", "hetero", "acyl"],
    },
)

# Create the biaryl scaffold.
scaffold_with_pyridazine = Scaffold(
    smiles="c1cc([R1])ccc1-c2cnnc([R2])c2",
    r_groups={
        1: ["hydrogen", "alkyl", "aryl", "halogen", "hetero", "acyl"],
        2: ["hydrogen", "alkyl", "aryl", "halogen", "hetero", "acyl"],
    },
)

# Create the biaryl scaffold.
# scaffold_with_triazine = Scaffold(
#     smiles="c1cc([R1])ccc1-c2cnn([R2])nc2",
#     r_groups={
#         1: ["hydrogen", "alkyl", "aryl", "halogen", "hetero", "acyl"],
#         2: ["hydrogen", "alkyl", "aryl", "halogen", "hetero", "acyl"],
#     },
# )

# Create the biaryl scaffold.
scaffold_with_furan = Scaffold(
    smiles="c1cc([R1])ccc1-c2coc([R2])c2",
    r_groups={
        1: ["hydrogen", "alkyl", "aryl", "halogen", "hetero", "acyl"],
        2: ["hydrogen", "alkyl", "aryl", "halogen", "hetero", "acyl"],
    },
)

# Create the biaryl scaffold.
scaffold_with_thiophene = Scaffold(
    smiles="c1cc([R1])ccc1-c2csc([R2])c2",
    r_groups={
        1: ["hydrogen", "alkyl", "aryl", "halogen", "hetero", "acyl"],
        2: ["hydrogen", "alkyl", "aryl", "halogen", "hetero", "acyl"],
    },
)

# Create the biaryl scaffold.
scaffold_with_benzene_two_subs = Scaffold(
    smiles="c1c([R1])cc([R2])cc1-c2ccc([R3])cc2",
    r_groups={
        1: ["hydrogen", "alkyl", "aryl", "halogen", "hetero", "acyl"],
        2: ["hydrogen", "alkyl", "aryl", "halogen", "hetero", "acyl"],
        3: ["hydrogen", "alkyl", "aryl", "halogen", "hetero", "acyl"],
    },
)

# Create the biaryl scaffold.
scaffold_with_benzofuran = Scaffold(
    smiles="c1cc([R1])ccc1-c2cc([R2])c3ccoc3c2",
    r_groups={
        1: ["hydrogen", "alkyl", "aryl", "halogen", "hetero", "acyl"],
        2: ["hydrogen", "alkyl", "aryl", "halogen", "hetero", "acyl"],
    },
)

# %% [markdown]
# # Using Openeye based constructor

# %%
from constructure.constructors import OpenEyeConstructor as Constructor
from constructure.substituents import SUBSTITUENTS

# %%
#         1: ["[R][S-]", "[R][O-]", "[R]N(C)(C)", "[R]N", "[R][N+]", "[R]NN", "[R]O", "[R]C(C)(C)(C)", "[R]C"],
#         2: ["[R]F", "[R]Cl", "[R]OC(#N)", "[R]C(=O)NC", "[R]C(=O)O", "[R]C(Cl)(Cl)(Cl)", "[R]S(=O)(=O)N", SUBSTITUENTS['nitro'], "[R][N+](#N)"],

substituents={1: ["[R][S-]", "[R][O-]","[R][H]"],
              2: ["[R]S(=O)(=O)N", "[R][N+](C)(C)(C)", SUBSTITUENTS['nitro'], "[R][N+](#N)","[R][H]"],
             }
              
#1
smiles_with_aryl = Constructor.enumerate_combinations(
    scaffold_with_aryl,
    substituents=substituents,
    validate=False,
    
)

#2
smiles_with_pyridyl = Constructor.enumerate_combinations(
    scaffold_with_pyridyl,
    substituents=substituents,
    validate=False,
)

#3
smiles_with_pyridyl_charged = Constructor.enumerate_combinations(
    scaffold_with_pyridyl_charged,
    substituents=substituents,
    validate=False,
)

#4
smiles_with_pyrrole = Constructor.enumerate_combinations(
    scaffold_with_pyrrole,
    substituents=substituents,
    validate=False,
)

#5
smiles_with_pyrimidine = Constructor.enumerate_combinations(
    scaffold_with_pyrimidine,
    substituents=substituents,
    validate=False,
)

#6
smiles_with_pyridazine = Constructor.enumerate_combinations(
    scaffold_with_pyridazine,
    substituents=substituents,
    validate=False,
)

#7
smiles_with_furan = Constructor.enumerate_combinations(
    scaffold_with_furan,
    substituents=substituents,
    validate=False,
)

#8
smiles_with_thiophene = Constructor.enumerate_combinations(
    scaffold_with_thiophene,
    substituents=substituents,
    validate=False,
)

#9
smiles_with_two_subs = Constructor.enumerate_combinations(
    scaffold_with_benzene_two_subs,
    substituents={
        1: ["[R][S-]", "[R][O-]"],
        2: ["[R][S-]", "[R][O-]"],
        3: ["[R]S(=O)(=O)N", "[R][N+](C)(C)(C)", SUBSTITUENTS['nitro'], "[R][N+](#N)"],
    }
)

# #10
smiles_with_benzofuran = Constructor.enumerate_combinations(
    scaffold_with_benzofuran,
    substituents=substituents,
    validate=False,
)

# %%
smiles =  smiles_with_aryl + smiles_with_pyridyl + smiles_with_pyridyl_charged + smiles_with_pyrrole + \
          smiles_with_pyrimidine + smiles_with_pyridazine + smiles_with_furan + \
          smiles_with_thiophene + smiles_with_two_subs + smiles_with_benzofuran
print(len(smiles))
# Out:
# 147

# %% [markdown]
# # Visualizing

# %%
# OpenEye
from constructure.utilities.openeye import smiles_to_image_grid

smiles_to_image_grid(smiles, "biaryl_smallset.pdf", cols=6)
smiles_to_image_grid(smiles, "biaryl_smallset.png", cols=6)
with open("biaryl_smallset.smi", "w") as file:
    file.write("\n".join(sorted(smiles)))

# %%
from IPython.display import Image
Image(filename='biaryl_smallset.png')

# %%
from openff.toolkit.topology import Molecule, Topology
from openff.toolkit.typing.engines.smirnoff import ForceField
# from openff.toolkit.topology.molecule import OEAroModelOpenEye 

forcefield = ForceField('./fit12.offxml', allow_cosmetic_attributes=True, aromaticity_model='OEAroModel_MDL')

dihedrals_list = []
for i in range(len(smiles)):
    mol = Molecule.from_smiles(smiles[i], allow_undefined_stereo=True)
    dihedrals_list.append(dihedrals_matching_torsion_param(mol, forcefield, 'TIG22'))

# %%
# Checking whether there are 4 torsions around the central bond that match the pattern
# `[#6X3H1:1]~[#6X3:2](~[#6X3H1])-[#6X3:3](~[#6X3H1])~[#6X3H1:4]`

for tup_list in dihedrals_list:
    assert len(tup_list) == 4
    assert tup_list[0][1:3] == tup_list[1][1:3]
    assert tup_list[0][1:3] == tup_list[2][1:3]
    assert tup_list[0][1:3] == tup_list[3][1:3]

# %%
elf10_wbo = []
fails = 0
mol_fail = []
for i in range(len(smiles)):
    mol = Molecule.from_smiles(smiles[i], allow_undefined_stereo=True)
    top = Topology.from_molecules([mol])
    try:
        mol.assign_fractional_bond_orders(bond_order_model="am1-wiberg-elf10")
    except:
        mol_fail.append(mol.to_smiles())
        fails += 1
        continue
    bond = mol.get_bond_between(dihedrals_list[i][0][1], dihedrals_list[i][0][2])
    elf10_wbo.append(bond.fractional_bond_order)
    if(bond.fractional_bond_order > 1.2):
        print(mol.to_smiles(), ", and WBO is ", bond.fractional_bond_order)
        display(mol.visualize(backend='openeye'))
# Out:
# [H]c1c(c(c(c(c1c2c(c(c(c(c2[H])[H])[S-])[H])[H])[H])[H])[N+]#N)[H] , and WBO is  1.2165984395426042
# [H]c1c(c(c(c(c1c2c(c(c(c(c2[H])[H])[O-])[H])[H])[H])[H])[N+]#N)[H] , and WBO is  1.3110940825674675
# [H]c1c(c(c(c(c1c2c(c(nc(c2[H])[N+]#N)[H])[H])[H])[H])[O-])[H] , and WBO is  1.2067354098270695
# [H]c1c(c(c(c(c1c2c(c([n+](c(c2[H])S(=O)(=O)N([H])[H])[H])[H])[H])[H])[H])[S-])[H] , and WBO is  1.2407817710955955
# [H]c1c(c(c(c(c1c2c(c([n+](c(c2[H])[N+](C([H])([H])[H])(C([H])([H])[H])C([H])([H])[H])[H])[H])[H])[H])[H])[S-])[H] , and WBO is  1.3377924607093634
# [H]c1c(c(c(c(c1c2c(c([n+](c(c2[H])N(=O)=O)[H])[H])[H])[H])[H])[S-])[H] , and WBO is  1.2656434198021569
# [H]c1c(c(c(c(c1c2c(c([n+](c(c2[H])[N+]#N)[H])[H])[H])[H])[H])[S-])[H] , and WBO is  1.2096461254317419
# [H]c1c(c(c(c(c1c2c(c([n+](c(c2[H])[H])[H])[H])[H])[H])[H])[S-])[H] , and WBO is  1.2222842263891602
# [H]c1c(c(c(c(c1c2c(c([n+](c(c2[H])S(=O)(=O)N([H])[H])[H])[H])[H])[H])[H])[O-])[H] , and WBO is  1.3275607067703354
# [H]c1c(c(c(c(c1c2c(c([n+](c(c2[H])[N+](C([H])([H])[H])(C([H])([H])[H])C([H])([H])[H])[H])[H])[H])[H])[H])[O-])[H] , and WBO is  1.4193407740335544
# [H]c1c(c(c(c(c1c2c(c([n+](c(c2[H])N(=O)=O)[H])[H])[H])[H])[H])[O-])[H] , and WBO is  1.3528813543268532
# [H]c1c(c(c(c(c1c2c(c([n+](c(c2[H])[N+]#N)[H])[H])[H])[H])[H])[O-])[H] , and WBO is  1.3015481110732772
# [H]c1c(c(c(c(c1c2c(c([n+](c(c2[H])[H])[H])[H])[H])[H])[H])[O-])[H] , and WBO is  1.3076746622511106
# [H]c1c(c(c(c(c1C2=C(N(C(=C2[H])[H])[N+]#N)[H])[H])[H])[O-])[H] , and WBO is  1.2758326102003608
# [H]c1c(c(c(c(c1c2c(nc(nc2[H])[N+]#N)[H])[H])[H])[S-])[H] , and WBO is  1.2317564684874327
# [H]c1c(c(c(c(c1c2c(nc(nc2[H])[N+](C([H])([H])[H])(C([H])([H])[H])C([H])([H])[H])[H])[H])[H])[O-])[H] , and WBO is  1.2099809298213973
# [H]c1c(c(c(c(c1c2c(nc(nc2[H])[N+]#N)[H])[H])[H])[O-])[H] , and WBO is  1.325991508079482
# [H]c1c(c(c(c(c1c2c(c(nnc2[H])[N+](C([H])([H])[H])(C([H])([H])[H])C([H])([H])[H])[H])[H])[H])[O-])[H] , and WBO is  1.2070323188476682
# [H]c1c(c(c(c(c1c2c(c(nnc2[H])[N+]#N)[H])[H])[H])[O-])[H] , and WBO is  1.2513622124469903

# %%
print("\n", len(elf10_wbo), "out of ", len(smiles), '\n', "Conformer generation failed for ", fails)
# Out:
#  146 out of  147
#  Conformer generation failed for  1

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
# plt.yscale("log")
plt.hist(elf10_wbo)
plt.title("Bridging central bond WBOs")
plt.xlabel("ELF0 WBO")
plt.ylabel("density")
# Out:
# Text(0, 0.5, 'density')

# %% [markdown]
# # Some troublesome molecules

# %%
mol_fail[0:10]
# Out:
# ['[H]c1c(c(c(c(c1C2=C(N(C(=C2[H])[H])[N+]#N)[H])[H])[H])[S-])[H]']

# %%
mol = Molecule.from_smiles(mol_fail[0])
mol.visualize()

# %%
from openff.toolkit.utils.toolkits import RDKitToolkitWrapper, AmberToolsToolkitWrapper
mol.assign_fractional_bond_orders(bond_order_model='am1-wiberg-elf10',)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-18-58b389e86bbc> in <module>
#       1 from openff.toolkit.utils.toolkits import RDKitToolkitWrapper, AmberToolsToolkitWrapper
# ----> 2 mol.assign_fractional_bond_orders(bond_order_model='am1-wiberg-elf10',)
#
# ~/anaconda3/envs/fb_dev_env/lib/python3.8/site-packages/openff/toolkit/topology/molecule.py in assign_fractional_bond_orders(self, bond_order_model, toolkit_registry, use_conformers)
#    3001         """
#    3002         if isinstance(toolkit_registry, ToolkitRegistry):
# -> 3003             return toolkit_registry.call(
#    3004                 "assign_fractional_bond_orders",
#    3005                 self,
#
# ~/anaconda3/envs/fb_dev_env/lib/python3.8/site-packages/openff/toolkit/utils/toolkits.py in call(self, method_name, raise_exception_types, *args, **kwargs)
#    5799                     for exception_type in raise_exception_types:
#    5800                         if isinstance(e, exception_type):
# -> 5801                             raise e
#    5802                     errors.append((toolkit, e))
#    5803
#
# ~/anaconda3/envs/fb_dev_env/lib/python3.8/site-packages/openff/toolkit/utils/toolkits.py in call(self, method_name, raise_exception_types, *args, **kwargs)
#    5795                 method = getattr(toolkit, method_name)
#    5796                 try:
# -> 5797                     return method(*args, **kwargs)
#    5798                 except Exception as e:
#    5799                     for exception_type in raise_exception_types:
#
# ~/anaconda3/envs/fb_dev_env/lib/python3.8/site-packages/openff/toolkit/utils/toolkits.py in assign_fractional_bond_orders(self, molecule, bond_order_model, use_conformers, _cls)
#    2547             if status is False:
#    2548
# -> 2549                 raise Exception(
#    2550                     "Unable to assign charges (in the process of calculating "
#    2551                     "fractional bond orders)"
#
# Exception: Unable to assign charges (in the process of calculating fractional bond orders)

# %% [markdown]
# # Discrepancy in wbo values from Chaya's paper
# https://chayast.github.io/wbo-manuscript/images/figure_3_2.svg

# %%
mol_smiles = ["[H]c1c(c(c(c(c1c2c(c(nc(c2[H])[H])[H])[H])[H])[H])[OH])[H]",
              "[H]c1c(c(c(c(c1c2c(c([n+](c(c2[H])[H])[H])[H])[H])[H])[H])[OH])[H]",
              "[H]c1c(c(c(c(c1c2c(c(nc(c2[H])[H])[H])[H])[H])[H])[O-])[H]",
              "[H]c1c(c(c(c(c1c2c(c([n+](c(c2[H])[H])[H])[H])[H])[H])[H])[O-])[H]",
             ]

# %%
for smi in mol_smiles:
    mol = Molecule.from_smiles(smi)
    display(mol.visualize(backend='openeye'))
    mol.assign_fractional_bond_orders(bond_order_model='am1-wiberg-elf10')
    dih_indices = dihedrals_matching_torsion_param(mol, forcefield, 'TIG22')
    print("Four dihedral indices: ", dih_indices)
    print("Central bond is between:", dih_indices[0][1], dih_indices[0][2])
    bond = mol.get_bond_between(dih_indices[0][1], dih_indices[0][2])
    print("WBO of central bond is ", bond.fractional_bond_order)
# Out:
# Four dihedral indices:  [(1, 6, 7, 8), (1, 6, 7, 12), (5, 6, 7, 8), (5, 6, 7, 12)]
# Central bond is between: 6 7
# WBO of central bond is  1.014903436282715
# Four dihedral indices:  [(1, 6, 7, 8), (1, 6, 7, 12), (5, 6, 7, 8), (5, 6, 7, 12)]
# Central bond is between: 6 7
# WBO of central bond is  1.0619769912406984
# Four dihedral indices:  [(1, 6, 7, 8), (1, 6, 7, 12), (5, 6, 7, 8), (5, 6, 7, 12)]
# Central bond is between: 6 7
# WBO of central bond is  1.0707395055685442
# Four dihedral indices:  [(1, 6, 7, 8), (1, 6, 7, 12), (5, 6, 7, 8), (5, 6, 7, 12)]
# Central bond is between: 6 7
# WBO of central bond is  1.30767466227044

# %% [markdown]
# #### WBOS
# | name    | Chaya's Paper | Calculated here |
# | ------- | ------------ | --------------- |
# |neutral | 1.01 | 1.01 |
# |cation  | 1.08 | 1.06 |
# |anion   | 1.11 | 1.07 |
# |zwitterion | 1.53  | 1.31 |
