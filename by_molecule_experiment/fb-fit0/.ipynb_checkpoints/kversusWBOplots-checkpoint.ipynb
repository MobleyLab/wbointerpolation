# %%
#imports
#Created by Jessica

import os
import json
import tempfile
from openforcefield.topology import Molecule, Topology
from openforcefield.typing.engines.smirnoff import (ForceField,
UnassignedValenceParameterException, BondHandler, AngleHandler,
ProperTorsionHandler, ImproperTorsionHandler,
vdWHandler)
from plot_td_energies import collect_td_targets_data, plot_td_targets_data
import pickle
from make_torsion_target_new import *
import shutil

force_balance_file = 'optimize.in'
# Out:
# Note: Failed to import the optional openff.evaluator package.

# %%
#functions
#sub_dir = [x[0] for x in os.walk(directory) if os.path.basename(x[0]).startswith('td')]

def makePlots(ds, ff, param_fit, ff_analysis, param_analysis, target_directory):
    """
    Description: 
    -Create k versus WBO plots
    -Create MM versus QM plots for each target 
    
    
    input:
    ds: List of dataset names
    ff: .offxml style format force field name
    param: List of parameters to generate plots for
    """
    
    #clear out target directory to create new targets based on dataset specifications 
    shutil.rmtree(target_directory)
    os.mkdir(target_directory)
    
    
    #make td Targets 
    for d in ds: 
        torsiondrive_data=download_torsiondrive_data(d)
        make_torsiondrive_target(d, torsiondrive_data, test_ff=None)
        
        

    #Create targets folder in subdirectory 
    force_balance_file = 'optimize.in'


    # Find which line of optimize.in the targets specificaiton begins at
    with open(force_balance_file, 'r') as f:
        replace_index = None
        force_balance_lines = f.readlines()
        for index,line in enumerate(force_balance_lines):
            try:
                #if 'name' in line[:4]:
                if line.startswith('name'):
                    replace_index = index
                    break
            except:
                pass
        #print(replace_index)

    count = 0
    
    

    
    #run force balance 
    #store the k1 and k2 values
    #getKval(k1, k2)=kval
    
    #store data in dictionary data {cmiles : [wbo, kval], }
    
    #create figure 
    
    return 
    
def getKval(k1, k2):
    """
    Determine the slope from the k1 and k2 value
    
    k1: 
    k2:
    """
    
    
    

    return kval 


def make_wbo_versus_k_plots(valDict):
    """
    Description: Make plots of k versus WBO and save plots to .pdf 
    
    
    input: 
    valDict: Dictionary of cmiles as keys and list of [wbo, kval] as the items 
    
    """
    
    
    
    
    return 



def make_MM_QM_plots(datasets):
    """
    datasets: MM_QM_Plots
    
    """

    
    
    
    return

# %%
#directory = '/Users/jessica/Downloads/release_1.2.0/fb-fit/targets/'
ff = '/Users/jessica/Documents/Grad_research/WBO_Torsions_ChayaPaper/release_1.3.0_2/fb-fit/fb-fit0/forcefield/test.offxml'

#be very careful when specifying this 
target_directory='/Users/jessica/Documents/Grad_research/wbointerpolation/by_molecule_experiment/fb-fit0/targets'
#all of the molecules there is torsions 
#break them out into subplots for the TIG parameters 


#Plot for molecules that use TIG5a, but use the TIG-fit0 plots 
#Plot for TIG3 

#run the same experiments with Carbon-Nitrogen central bonds parameters 


ds=['SMIRNOFF Coverage Torsion Set 1']
ff='/Users/jessica/Documents/Grad_research/WBO_Torsions_ChayaPaper/release_1.3.0_2/fb-fit/fb-fit0/forcefield/test.offxml'
param_fit=['TIG-fit0'] 
param_analysis=[]
ff_analysis=''

makePlots(ds, ff, param_fit, ff_analysis, param_analysis, target_directory)
# Out:
# Loading TorsionDrive Scans from [ SMIRNOFF Coverage Torsion Set 1 ] spec [default]
# Found 585 data entries
# Found 585 torsiondrive records
#     1 : [CH3:1][O:2][CH:3]([OH:4])OC                       status COMPLETE
#     2 : [CH3:1][O:2][CH:3](O)[O:4]C                        status COMPLETE
#     3 : CO[CH:3]([OH:4])[O:2][CH3:1]                       status COMPLETE
#     4 : C[O:4][CH:3](O)[O:2][CH3:1]                        status COMPLETE
#     5 : [H:4][C:3](O)([O:2][CH3:1])OC                      status COMPLETE
#     6 : [H:4][C:3](O)(OC)[O:2][CH3:1]                      status COMPLETE
#     7 : [H:4][CH2:3][O:2][CH:1](O)OC                       status COMPLETE
#     8 : [H:4][O:3][CH:2]([O:1]C)OC                         status COMPLETE
#     9 : [H:4][O:3][CH:2](OC)[O:1]C                         status COMPLETE
#    10 : [H:1][C:2]([O:3][H:4])(OC)OC                       status COMPLETE
#    11 : [H:3][CH2:1][S:2][H:4]                             status COMPLETE
#    12 : [H:1][CH2:3][S:2][H:4]                             status COMPLETE
#    13 : [H:3][CH2:1][O:2][H:4]                             status COMPLETE
#    14 : [H:1][CH2:3][O:2][H:4]                             status COMPLETE
#    15 : [H:4][O:3][CH2:2][CH3:1]                           status COMPLETE
#    16 : [H:4][CH2:3][CH2:2][OH:1]                          status COMPLETE
#    17 : [H:3][CH2:1][CH:2]([H:4])O                         status COMPLETE
#    18 : [H:1][CH2:3][CH:2]([H:4])O                         status COMPLETE
#    19 : [CH:1]#[C:2][c:3]1[cH:4]cccc1                      status ERROR
#    20 : [CH:1]#[C:2][c:3]1cccc[cH:4]1                      status ERROR
#    21 : C#[C:1][c:2]1[cH:3][cH:4]ccc1                      status COMPLETE
#    22 : [H:4][c:3]1cccc[c:2]1[C:1]#C                       status COMPLETE
#    23 : C#[C:1][c:2]1ccc[cH:4][cH:3]1                      status COMPLETE
#    24 : C#C[c:4]1[cH:3][cH:2][cH:1]cc1                     status COMPLETE
#    25 : [H:4][C:3]#[C:2][c:1]1ccccc1                       status ERROR
#    26 : [H:4][NH+:3]=[CH:2][NH2:1]                         status COMPLETE
#    27 : [H:2][C:1](=[NH+:3][H:4])N                         status COMPLETE
#    28 : [H:4][NH:2][CH:3]=[NH2+:1]                         status COMPLETE
#    29 : [H:3][C:1](=[NH2+])[NH:2][H:4]                     status COMPLETE
#    30 : [H:4][NH:3]/[CH:2]=[N:1]/[H]                       status COMPLETE
#    31 : [H:4]/[N:2]=[CH:3]/[NH2:1]                         status COMPLETE
#    32 : [H:3]/[C:1](=[N:2]\[H:4])/N                        status COMPLETE
#    33 : [H:2]/[C:1](=N\[H])/[NH:3][H:4]                    status COMPLETE
#    34 : [H:4][NH:3]/[CH:2]=[N:1]\[H]                       status COMPLETE
#    35 : [H:4]/[N:2]=[CH:3]\[NH2:1]                         status COMPLETE
#    36 : [H:3]/[C:1](=[N:2]/[H:4])/N                        status ERROR
#    37 : [H:2]/[C:1](=N/[H])/[NH:3][H:4]                    status COMPLETE
#    38 : C[S@](=[N-])(=O)[NH:4][CH:3]1[CH2:1][CH2:2]1       status COMPLETE
#    39 : [H:4][C:3]1([CH2:1][CH2:2]1)N[S@@](=[N-])(=O)C     status COMPLETE
#    40 : [H:4][CH:3]1[CH2:1][CH:2]1N[S@@](=[N-])(=O)C       status COMPLETE
#    41 : C[S@](=[N-])(=O)[NH:4][CH:3]1[CH2:2][CH2:1]1       status COMPLETE
#    42 : C[S@:4](=[N-])(=O)[NH:3][CH:2]1[CH2:1]C1           status COMPLETE
#    43 : C[S@:4](=[N-])(=O)[NH:3][CH:2]1C[CH2:1]1           status COMPLETE
#    44 : [H:4][N:3]([CH:2]1[CH2:1]C1)[S@@](=[N-])(=O)C      status COMPLETE
#    45 : [H:4][N:3]([CH:2]1C[CH2:1]1)[S@@](=[N-])(=O)C      status COMPLETE
#    46 : [CH3:4][S@:3](=[N-])(=O)[NH:2][CH:1]1CC1           status COMPLETE
#    47 : C[S@:3](=[N-:4])(=O)[NH:2][CH:1]1CC1               status COMPLETE
#    48 : [H:4][N:3](C1CC1)[S@@:2](=[N-:1])(=O)C             status COMPLETE
#    49 : C[S@:3](=[N-])(=[O:4])[NH:2][CH:1]1CC1             status COMPLETE
#    50 : [H:4][N:3](C1CC1)[S@@:2](=[N-])(=O)[CH3:1]         status COMPLETE
#    51 : [H:4][CH2:3][S@:2](=[N-:1])(=O)NC1CC1              status COMPLETE
#    52 : [H:4][CH2:3][S@:2](=[N-])(=O)[NH:1]C1CC1           status COMPLETE
#    53 : [H:4][CH:3]1C[CH:2]1[NH:1][S@@](=[N-])(=O)C        status COMPLETE
#    54 : [H:3][CH:1]1[CH:2](C1N[S@@](=[N-])(=O)C)[H:4]      status COMPLETE
#    55 : [H:4][N:3](C1CC1)[S@@:2](=[N-])(=[O:1])C           status COMPLETE
#    56 : [H:4][C:3]1(CC1)[NH:2][S@@:1](=[N-])(=O)C          status COMPLETE
#    57 : [H:1][C:2]1(CC1)[N:3]([H:4])[S@@](=[N-])(=O)C      status COMPLETE
#    58 : C[S@@:4](=N)(=O)[N-:3][CH:2]1[CH2:1]C1             status COMPLETE
#    59 : C[S@@:4](=N)(=O)[N-:3][CH:2]1C[CH2:1]1             status COMPLETE
#    60 : [H:4][C:3]1(CC1)[N-:2][S@:1](=N)(=O)C              status COMPLETE
#    61 : [CH3:4][S@@:3](=N)(=O)[N-:2][CH:1]1CC1             status COMPLETE
#    62 : C[S@@:3](=[NH:4])(=O)[N-:2][CH:1]1CC1              status COMPLETE
#    63 : C[S@@:3](=N)(=[O:4])[N-:2][CH:1]1CC1               status COMPLETE
#    64 : [H:4][N:3]=[S@@:2](=O)([CH3:1])[N-]C1CC1           status COMPLETE
#    65 : [H:4][N:3]=[S@@:2](=O)(C)[N-:1]C1CC1               status COMPLETE
#    66 : [H:4][N:3]=[S@@:2](=[O:1])(C)[N-]C1CC1             status COMPLETE
#    67 : C[S@@:4](=[N-])(=O)[NH:3][CH:2]1[CH2:1]C1          status COMPLETE
#    68 : C[S@@:4](=[N-])(=O)[NH:3][CH:2]1C[CH2:1]1          status COMPLETE
#    69 : [H:4][N:3]([CH:2]1[CH2:1]C1)[S@](=[N-])(=O)C       status COMPLETE
#    70 : [H:4][N:3]([CH:2]1C[CH2:1]1)[S@](=[N-])(=O)C       status COMPLETE
#    71 : [CH3:4][S@@:3](=[N-])(=O)[NH:2][CH:1]1CC1          status COMPLETE
#    72 : C[S@@:3](=[N-])(=[O:4])[NH:2][CH:1]1CC1            status COMPLETE
#    73 : [H:4][N:3](C1CC1)[S@:2](=[N-])(=O)[CH3:1]          status COMPLETE
#    74 : [H:4][N:3](C1CC1)[S@:2](=[N-])(=[O:1])C            status COMPLETE
#    75 : [H:4][C:3]1(CC1)[NH:2][S@:1](=[N-])(=O)C           status COMPLETE
#    76 : [H:1][C:2]1(CC1)[N:3]([H:4])[S@](=[N-])(=O)C       status COMPLETE
#    77 : C[S@:4](=N)(=O)[N-:3][CH:2]1[CH2:1]C1              status COMPLETE
#    78 : C[S@:4](=N)(=O)[N-:3][CH:2]1C[CH2:1]1              status COMPLETE
#    79 : [H:4][N:3]=[S@:2](=O)([CH3:1])[N-]C1CC1            status COMPLETE
#    80 : [H:4][N:3]=[S@:2](=O)(C)[N-:1]C1CC1                status COMPLETE
#    81 : C[S@@:4](=N)(=O)[NH:3][CH:2]1[CH2:1]C1             status COMPLETE
#    82 : [H:4][N:3]([CH:2]1[CH2:1]C1)[S@](=N)(=O)C          status COMPLETE
#    83 : [CH3:4][S@@:3](=N)(=O)[NH:2][CH:1]1CC1             status COMPLETE
#    84 : C[S@@:3](=N)(=[O:4])[NH:2][CH:1]1CC1               status COMPLETE
#    85 : [H:4][N:3](C1CC1)[S@:2](=N)(=O)[CH3:1]             status COMPLETE
#    86 : [H:4][N:3](C1CC1)[S@:2](=N)(=[O:1])C               status COMPLETE
#    87 : [H:4][C:3]1(CC1)[NH:2][S@:1](=N)(=O)C              status COMPLETE
#    88 : [H:1][C:2]1(CC1)[N:3]([H:4])[S@](=N)(=O)C          status COMPLETE
#    89 : [CH3:4][S@:3](=N)(=O)[NH:2][CH:1]1CC1              status COMPLETE
#    90 : C[S@:3](=N)(=[O:4])[NH:2][CH:1]1CC1                status COMPLETE
#    91 : [H:4][N:3](C1CC1)[S@@:2](=N)(=O)[CH3:1]            status COMPLETE
#    92 : [H:4][N:3](C1CC1)[S@@:2](=N)(=[O:1])C              status COMPLETE
#    93 : [H:4][C:3]1(CC1)[NH:2][S@@:1](=N)(=O)C             status COMPLETE
#    94 : [H:1][C:2]1(CC1)[N:3]([H:4])[S@@](=N)(=O)C         status COMPLETE
#    95 : C[C@@]1(CC(=O)N1)[c:3]2n[cH:1][cH:2][s:4]2         status COMPLETE
#    96 : C[C@@]1(CC(=O)N1)[c:3]2[n:4]c[cH:1][s:2]2          status COMPLETE
#    97 : C[C@@:4]1(CC(=O)N1)[c:3]2[n:2][cH:1]cs2            status COMPLETE
#    98 : C[C@@]1(CC(=O)N1)[c:4]2[n:3][cH:2][cH:1]s2         status COMPLETE
#    99 : C[C@@:4]1(CC(=O)N1)[c:3]2nc[cH:1][s:2]2            status COMPLETE
#   100 : C[C@@:2]1([CH2:3][C:4](=O)N1)[c:1]2nccs2           status COMPLETE
#   158 : [H:4][c:3]1cs[c:1]([nH+:2]1)[C@]2(CC(=O)N2)C       status COMPLETE
#   159 : C[C@@:3]1([CH2:4][C:1](=O)[NH:2]1)c2[nH+]ccs2      status COMPLETE
#   160 : C[C@@:1]1([CH2:2][C:3](=O)[NH:4]1)c2[nH+]ccs2      status ERROR
#   161 : C[C@@:2]1(CC(=O)[NH:1]1)[c:3]2[nH+]cc[s:4]2        status COMPLETE
#   162 : [H:4][CH:3]1[C:2](=[O:1])N[C@@]1(C)c2[nH+]ccs2     status COMPLETE
#   163 : C[C@]1(CC(=O)N1)[c:4]2[n:3][cH:2][cH:1]s2          status COMPLETE
#   164 : C[C@:4]1(CC(=O)N1)[c:3]2nc[cH:1][s:2]2             status COMPLETE
#   165 : C[C@:2]1(C[C:4](=O)[NH:3]1)[c:1]2nccs2             status COMPLETE
#   166 : [H:4][c:3]1cs[c:1]([n:2]1)[C@@]2(CC(=O)N2)C        status COMPLETE
#   167 : C[C@:1]1([CH2:2][C:3](=O)[NH:4]1)c2nccs2           status ERROR
#   168 : C[C@:2]1(CC(=O)[NH:1]1)[c:3]2ncc[s:4]2             status COMPLETE
#   169 : [cH:1]1[cH:2][o:3][n:4]c1C2(CC2)C(=O)[O-]          status COMPLETE
#   170 : [H:4][c:3]1cc([n:1][o:2]1)C2(CC2)C(=O)[O-]         status COMPLETE
#   171 : [cH:1]1con[c:2]1[C:3]2(CC2)[C:4](=O)[O-]           status COMPLETE
#   172 : [cH:1]1con[c:2]1[C:3]2([CH2:4]C2)C(=O)[O-]         status COMPLETE
#   173 : [cH:1]1con[c:2]1[C:3]2(C[CH2:4]2)C(=O)[O-]         status COMPLETE
#   174 : [cH:2]1[cH:1]on[c:3]1[C:4]2(CC2)C(=O)[O-]          status COMPLETE
#   175 : [cH:2]1[cH:1]o[n:4][c:3]1C2(CC2)C(=O)[O-]          status COMPLETE
#   176 : [H:4][c:3]1con[c:2]1[C:1]2(CC2)C(=O)[O-]           status COMPLETE
#   177 : [H:4][c:3]1co[n:1][c:2]1C2(CC2)C(=O)[O-]           status COMPLETE
#   178 : c1[cH:1][o:2][n:4][c:3]1C2(CC2)C(=O)[O-]           status COMPLETE
#   179 : c1con[c:1]1[C:2]2(CC2)[C:3](=O)[O-:4]              status COMPLETE
#   180 : c1co[n:4][c:3]1[C:2]2(CC2)[C:1](=O)[O-]            status COMPLETE
#   181 : c1conc1[C:2]2([CH2:1]C2)[C:3](=O)[O-:4]            status COMPLETE
#   182 : c1conc1[C:2]2(C[CH2:1]2)[C:3](=O)[O-:4]            status COMPLETE
#   183 : c1con[c:1]1[C:2]2(CC2)[C:3](=[O:4])[O-]            status COMPLETE
#   184 : c1co[n:4][c:3]1[C:2]2([CH2:1]C2)C(=O)[O-]          status COMPLETE
#   185 : c1co[n:4][c:3]1[C:2]2(C[CH2:1]2)C(=O)[O-]          status COMPLETE
#   186 : c1conc1[C:2]2([CH2:1]C2)[C:3](=[O:4])[O-]          status COMPLETE
#   187 : c1conc1[C:2]2(C[CH2:1]2)[C:3](=[O:4])[O-]          status COMPLETE
#   188 : [cH:1]1[cH:2][o:3][n:4]c1C2(CC2)C(=O)O             status COMPLETE
#   189 : [H:4][c:3]1cc([n:1][o:2]1)C2(CC2)C(=O)O            status COMPLETE
#   190 : [cH:1]1con[c:2]1[C:3]2(CC2)[C:4](=O)O              status COMPLETE
#   191 : [cH:1]1con[c:2]1[C:3]2([CH2:4]C2)C(=O)O            status COMPLETE
#   192 : [cH:1]1con[c:2]1[C:3]2(C[CH2:4]2)C(=O)O            status COMPLETE
#   193 : [cH:2]1[cH:1]on[c:3]1[C:4]2(CC2)C(=O)O             status COMPLETE
#   194 : c1[cH:1][o:2][n:4][c:3]1C2(CC2)C(=O)O              status COMPLETE
#   195 : c1con[c:1]1[C:2]2(CC2)[C:3](=[O:4])O               status COMPLETE
#   196 : c1con[c:1]1[C:2]2(CC2)[C:3](=O)[OH:4]              status COMPLETE
#   197 : c1co[n:4][c:3]1[C:2]2([CH2:1]C2)C(=O)O             status COMPLETE
#   198 : c1co[n:4][c:3]1[C:2]2(C[CH2:1]2)C(=O)O             status COMPLETE
#   199 : c1conc1[C:2]2([CH2:1]C2)[C:3](=[O:4])O             status COMPLETE
#   200 : c1conc1[C:2]2(C[CH2:1]2)[C:3](=[O:4])O             status COMPLETE
#   201 : c1conc1[C:2]2([CH2:1]C2)[C:3](=O)[OH:4]            status COMPLETE
#   202 : c1conc1[C:2]2(C[CH2:1]2)[C:3](=O)[OH:4]            status COMPLETE
#   203 : [H:4][O:3][C:2](=O)[C:1]1(CC1)c2ccon2              status COMPLETE
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-58252635c0e5> in <module>
#      20 ff_analysis=''
#      21
# ---> 22 makePlots(ds, ff, param_fit, ff_analysis, param_analysis, target_directory)
#      23
#      24
#
# <ipython-input-2-415c033a567c> in makePlots(ds, ff, param_fit, ff_analysis, param_analysis, target_directory)
#      22     #make td Targets
#      23     for d in ds:
# ---> 24         torsiondrive_data=download_torsiondrive_data(d)
#      25         make_torsiondrive_target(d, torsiondrive_data, test_ff=None)
#      26
#
# ~/Documents/Grad_research/wbointerpolation/by_molecule_experiment/fb-fit0/make_torsion_target_new.py in download_torsiondrive_data(dataset_name)
#      98             torsiondrive_data[entry_index] = {
#      99                 'initial_molecules': client.query_molecules(td_record.initial_molecule),
# --> 100                 'final_molecules': td_record.get_final_molecules(),
#     101                 'final_energies': td_record.get_final_energies(),
#     102                 'final_gradients': {gid: np.array(res.return_result) for gid, res in td_record.get_final_results().items()},
#
# ~/miniconda3/envs/openff-dev/lib/python3.7/site-packages/qcportal/models/torsiondrive.py in get_final_molecules(self, key)
#     299         if "final_molecules" not in self.cache:
#     300
# --> 301             map_id_key = self._get_min_optimization_map()
#     302
#     303             opt_ids = list(map_id_key.keys())
#
# ~/miniconda3/envs/openff-dev/lib/python3.7/site-packages/qcportal/models/torsiondrive.py in _get_min_optimization_map(self)
#     444             k = self._serialize_key(k)
#     445             minpos = self.minimum_positions[k]
# --> 446             final_opt_id = tasks[minpos]
#     447             map_id_key[final_opt_id] = k
#     448
#
# IndexError: list index out of range
